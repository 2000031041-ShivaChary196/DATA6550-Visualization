# %% [markdown]
# # Group Project-2
# # Create Visualizations- Good,the bad,the Ugly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### We are using train.csv because it contains the survival outcome variables(0=did not durvive,1=survived), which make easy to analyze patterns and create both ethical and misleading visualizations.

# %% [markdown]
# # ACCURATE VISUALIZATIONS

# %% [markdown]
# # Visualization By gender

# %%
plt.figure()
sns.barplot(x="Sex", y="Survived", data=df)
plt.title("Survival Rate by Gender")
plt.ylabel("Survival Rate")
plt.xlabel("Gender")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# #### This visualization compares survival rates between male and female passengers.Out of 577 male passengers, only 109 survived (18.9%). In contrast, 233 out of 314 female passengers survived (74.2%). This large difference highlights the strong impact of gender on survival outcomes.

# %% [markdown]
# # Visulization by Passenger class

# %%
plt.figure()
sns.barplot(x="Pclass", y="Survived", data=df)
plt.title("Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# #### This visualization compares survival rates across passenger classes.Out of 216 first-class passengers, 136 survived (63.0%).Among 184 second-class passengers, 87 survived (47.3%).In contrast, only 119 out of 491 third-class passengers survived (24.2%).

# %% [markdown]
# # Visualization of Survival rate of Embarkation Port

# %%
plt.figure()
sns.barplot(x="Embarked", y="Survived", data=df)
plt.title("Survival Rate by Port of Embarkation")
plt.xlabel("Embarkation Port (C = Cherbourg, Q = Queenstown, S = Southampton)")
plt.ylabel("Survival Rate")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# #### This visualization compares survival rates based on the port where passengers boarded the Titanic.Passengers who boarded at Cherbourg had the highest survival rate(55.4%), followed by Queenstown, while Southampton passengers had the lowest survival rate (39.0%),(33.7%), i think the embarkation location influenced survival outcomes.

# %% [markdown]
# # Visualization of survivals by the fare Distribution

# %%
plt.figure()
sns.boxplot(x="Survived", y="Fare", data=df)
plt.title("Fare Distribution by Survival")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Fare Paid")
plt.show()

# %% [markdown]
# #### This boxplot compares the fare paid by passengers who did not survive (0) and those who survived (1).By the plot we can say that Passengers who survived generally paid higher fares than those who did not survive.

# %% [markdown]
# # MISLEADING VISUALIZATION

# %% [markdown]
# # Bad visulization for port embarkment

# %%
plt.figure()
sns.barplot(x="Embarked", y="Survived", data=df)
plt.title("Survival Rate by Port of Embarkation")
plt.xlabel("Embarkation Port")
plt.ylabel("Survival Rate")
plt.ylim(0.30, 0.60)
plt.show()

# %% [markdown]
# #### This chart exaggerates the differences between the ports because the y-axis does not start at zero. By cutting off the baseline (upto 0.30 to 0.0 on y-axis), it makes the survival gap look much bigger than it actually is, which can mislead the viewer.

# %%
# cherypicking the data
filtered = df[df["Embarked"].isin(["C", "S"])]
plt.figure()
sns.barplot(x="Embarked", y="Survived", data=filtered)
plt.title("Survival Rate by Selected Ports")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# #### This chart is misleading because it only shows selected ports instead of all three embarkation locations. By excluding Queenstown (Q), it hides part of the data and can make the difference between Southampton and Cherbourg look more dramatic than it actually is.

# %% [markdown]
# # Bad visualization for the Fare Distributions

# %%
plt.figure()
sns.boxplot(x="Survived", y="Fare", data=df, showfliers=False)
plt.title("Fare Distribution by Survival")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Fare Paid")
plt.show()

# %% [markdown]
# #### This chart is misleading because the y-axis is limited (up to around 120), which hides the very high fare outliers that exist in the dataset. By cutting off extreme values, it reduces the visible difference in fare distribution between survivors and non-survivors and makes the gap appear smaller than it actually is.
